# %%
import matplotlib.pyplot as plt

a=1,2,3,4
plt.plot(a)

# %%
# Plot Two-dimensional array
import numpy as np
import matplotlib.pyplot as plt

a=np.arange(6).reshape(3,2)
plt.plot(a)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

a=np.arange(9).reshape(3,3)
plt.plot(a)
plt.show()

# %%
# Plot Two-dimensional array
import numpy as np
import matplotlib.pyplot as plt

a=np.array([[3,5],[2,0],[1,6]])
plt.plot(a)
plt.show()

# %%
# Plot Three-dimensional array
import numpy as np
import matplotlib.pyplot as plt

a=np.array([[3,5,4],[2,0,9],[1,6,0]])
plt.plot(a)
plt.show()

# %%
*******************   Pyplot Formatstr   ***********************

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4], [1,4,9,16], 'ro')
plt.axis([0, 6, 0, 20])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4], [1,4,9,16], 'bo')
plt.axis([0, 6, 0, 20])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


def test(ax):
    ax.plot([1, 2])

    ax.locator_params(nbins=3)
    ax.set_xlabel('x-label')
    ax.set_ylabel('y-label')
    ax.set_title('Title')

plt.close('all')

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2)
test(ax1)
test(ax2)
test(ax3)
test(ax4)
plt.tight_layout()

# %%
# Using AxesGrid1 with colorbar

from mpl_toolkits.axes_grid1 import make_axes_locatable

plt.close('all')
arr = np.arange(100).reshape((10, 10))
fig = plt.figure(figsize=(4, 4))
im = plt.imshow(arr, interpolation="none")

divider = make_axes_locatable(plt.gca())
cax = divider.append_axes("right", "5%", pad="3%")
plt.colorbar(im, cax=cax)

plt.tight_layout()

# %%
**********************   Labeling   ************************

# %%
# xlabel and ylabel

import matplotlib.pyplot as plt

a=np.arange(0,1.0,0.01)
plt.plot(a, a**2)

plt.xlabel('time')
plt.ylabel('distance')

plt.show()

# %%
*******************  Multiple Figures   **********************

# %%
# Creating three figure in which first one has two subplot

import matplotlib.pyplot as plt
import numpy as np

t = np.arange(0.0, 2.0, 0.01)
s1 = np.sin(3*np.pi*t)
s2 = np.cos(4*np.pi*t)

plt.figure(1)
plt.subplot(211)
plt.plot(t, s1)
plt.subplot(212)
plt.plot(t, 2*s1,'g-')

plt.figure(2)
plt.plot(t, s2)

plt.figure(3)
plt.subplot(211)
plt.plot(t, s2, 'ro')


plt.show()

# %%
*********************   Charts   *********************

# %%
# Simple Histogram

import numpy as np
from numpy import pi,sin,cos, tan
import matplotlib.pyplot as plt

x = np.random.randn(500)

plt.hist(x)

plt.show()

# %%
# Simple Histogram

import numpy as np
from numpy import pi,sin,cos, tan
import matplotlib.pyplot as plt

x = np.random.randn(500)
y = 50

plt.hist(x, y)

plt.show()

# %%
# Simple Histogram - Adding parameters to hist() function

import numpy as np
from numpy import pi,sin,cos, tan
import matplotlib.pyplot as plt

x = np.random.randn(500)
y = 50

plt.hist(x, y,  density=True, facecolor='g', alpha=0.55)

plt.show()

# %%
# 2D Histogram

from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt
import numpy as np

# normal distribution center at x=0 and y=5
x = np.random.randn(1000)
y = np.random.randn(1000) + 5

plt.hist2d(x, y )
plt.colorbar()
plt.show()

# %%
# 2D Histogram

from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt
import numpy as np

# normal distribution center at x=0 and y=5
x = np.random.randn(100000)
y = np.random.randn(100000) + 5

plt.hist2d(x, y, bins=40, norm=LogNorm() )
plt.colorbar()
plt.show()

# %%
# Simple Histogram - Adding parameters to hist() function

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

x = np.random.randn(50000)

plt.hist2d(x, x**2, bins=40, norm=LogNorm())

plt.show()

# %%
*** Creating Path

# %%
# Path and Patches

import matplotlib.pyplot as plt
from matplotlib.path import Path
import matplotlib.patches as patches

verts = [
    (0., 0.), # left, bottom
    (0., 1.), # left, top
    (1., 1.), # right, top
    (1., 0.), # right, bottom
    (0., 0.), # ignored
    ]

codes = [Path.MOVETO,
         Path.LINETO,
         Path.LINETO,
         Path.LINETO,
         Path.CLOSEPOLY,
         ]

path = Path(verts, codes)

fig, ax = plt.subplots()

patch = patches.PathPatch(path, facecolor='lightgreen', lw=2)

ax.add_patch(patch)
ax.set_xlim(-2,2)
ax.set_ylim(-2,2)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

Y, X = np.mgrid[-3:3:100j, -3:3:100j]
U = -1 - X**2 + Y
V = 1 + X - Y**2
speed = np.sqrt(U*U + V*V)

plt.streamplot(X, Y, U, V, color=U, linewidth=2, arrowsize=1, arrowstyle='-|>', cmap=plt.cm.autumn)
plt.colorbar()

plt.show()

# %%
*** Ellipses

matplotlib.patches.Ellipse

class matplotlib.patches.Ellipse(xy, width, height, angle=0.0, **kwargs)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Ellipse

delta = 45.0  # degrees

angles = np.arange(0, 360 + delta, delta)
ells = [Ellipse((1, 1), 4, 2, a) for a in angles]

a = plt.subplot(111, aspect='equal')

for e in ells:
    e.set_clip_box(a.bbox)
    e.set_alpha(0.1)
    a.add_artist(e)

plt.xlim(-2, 4)
plt.ylim(-1, 3)

plt.show()

# %%
*** Bar Chart

Bar charts are simple to create using the bar() command, which includes customizations such as error bars:
    
matplotlib.pyplot.bar(left, height, width=0.80000000000000004, bottom=None, hold=None, **kwargs)

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
objects = ('Python', 'C++', 'Java', 'Perl', 'Scala')
y_pos = np.arange(len(objects))
performance = [12,8,6,4,2]
 
plt.bar( y_pos,performance, align='center', alpha=0.5, width=0.2)

plt.xticks(y_pos, objects)
plt.ylabel('Usage')
plt.title('Programming language usage')
 
plt.show()

# %%
import matplotlib.pyplot as plt
 
objects = ('Python', 'C++', 'Java', 'Perl', 'Scala')
y_pos = np.arange(len(objects))
performance = [12,8,6,4,2]
easytolearn = [10,7,4,3,3]
 
plt.bar( y_pos,performance, align='center', alpha=0.5, width=0.2)
plt.bar( y_pos+bar_width,easytolearn, align='center', alpha=0.5,  width=0.2)

plt.xticks(y_pos, objects)
plt.ylabel('Usage')
plt.title('Programming language usage and Easy to Learn Languages')
 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-1dd6becfe180> in <module>
#       7
#       8 plt.bar( y_pos,performance, align='center', alpha=0.5, width=0.2)
# ----> 9 plt.bar( y_pos+bar_width,easytolearn, align='center', alpha=0.5,  width=0.2)
#      10
#      11 plt.xticks(y_pos, objects)
#
# NameError: name 'bar_width' is not defined

# %%
*** Pie Chart

matplotlib.pyplot.pie(x, explode=None, labels=None, colors=None, autopct=None, pctdistance=0.59999999999999998, shadow=False, labeldistance=1.1000000000000001, startangle=None, radius=None, counterclock=True, wedgeprops=None, textprops=None, hold=None)

# %%
# Simple Pie Chart

import matplotlib.pyplot as plt
sizes = [15, 30, 45, 10]

plt.pie(sizes)

# Set aspect ratio to be equal so that pie is drawn as a circle.
plt.axis('equal')

plt.show()

# %%
# Above Pie Chart with properly defined attributes

import matplotlib.pyplot as plt

# The slices will be ordered and plotted counter-clockwise.
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
explode = (0, 0.1, 0, 0) # only "explode" the 2nd slice (i.e. 'Hogs')

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)

# Set aspect ratio to be equal so that pie is drawn as a circle.
plt.axis('equal')

plt.show()

# %%
*** Scatter

The scatter() command makes a scatter plot with (optional) size and color arguments. ]

matplotlib.pyplot.scatter(x, y, s=20, c=u'b', marker=u'o', cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, verts=None, hold=None, **kwargs)

# %%
# Simple Program

import numpy as np
import matplotlib.pyplot as plt

x=[2,3,6,8,4,5,8,9,2,1,5,3,9,5,7,2,0,1,4]
y=[2,8,9,2,6,8,4,5,8,9,2,1,5,3,9,5,7,2,3]

plt.scatter(x,y)
plt.show()

# %%
 #Another Example

import numpy as np
import matplotlib.pyplot as plt


N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2 # 0 to 15 point radiuses

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
*** Fill Command

matplotlib.pyplot.fill(*args, **kwargs)

# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(0, 1)
y = np.sin(4 * np.pi * x) * np.exp(-5 * x)

plt.fill(x, y, 'g')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


r = np.arange(0, 3.0, 0.01)
theta = 2 * np.pi * r

ax = plt.subplot(111, polar=True)
ax.plot(theta, r, color='r', linewidth=3)
ax.set_rmax(2.0)
ax.grid(True)

ax.set_title("A line plot on a polar axis", va='bottom')
plt.show()
